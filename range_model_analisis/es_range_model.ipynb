# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data frame

# %%
df = pd.read_csv('/home/juan500/Documents/Develops/sp500_range_proyect/sp500_MLops/data/processed/processed_sp500.csv')
df.head()
# Out:
#          date  close_log  high_log   low_log  target_high  target_low  \
# 0  2005-01-05   7.076434  7.084000  7.076417     0.003931   -0.003651
# 1  2005-01-06   7.079934  7.083077  7.076037     0.006643   -0.000397
# 2  2005-01-07   7.078502  7.083556  7.075099     0.003622   -0.004835
# 3  2005-01-10   7.081919  7.085717  7.077329     0.007216   -0.001172
# 4  2005-01-11   7.075800  7.081919  7.073634     0.000000   -0.008285
#
#    log_target  log_return  close_log_lag1  Upper_Wick_lag1  Lower_Wick_lag1  \
# 0   -0.003634   -0.011740        7.080069         0.014863         0.002242
# 1    0.003500   -0.003634        7.076434         0.007566         0.000017
# 2   -0.001432    0.003500        7.079934         0.003143         0.003897
# 3    0.003417   -0.001432        7.078502         0.005054         0.003403
# 4   -0.006118    0.003417        7.081919         0.003799         0.004589
#
#    Vol_Diaria_lag1  Vol_Rango_Log_lag1
# 0         0.008807            0.036650
# ...
